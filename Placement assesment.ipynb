# %% [markdown]
# # Business Understanding

# %% [markdown]
# The target variable in the data set is income level, which shows whether a person earns more than 50,000 per year or not, based on 14 features containing information on age, education, education-num, gender, native-country, marital status, final weight, occupation, work classification, gender, race, hours-per-week, capital loss, and capital gain.

# %% [markdown]
# # Data Mining

# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import sweetviz as sv

# %%
data=pd.read_csv("https://raw.githubusercontent.com/Aditya-Mankar/Census-Income-Prediction/master/adult.csv")

# %%
data.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %%
data.shape
# Out:
# (32561, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# # Data Cleaning

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
data.describe().T
# Out:
#                   count           mean            std      min       25%  \
# age             32561.0      38.581647      13.640433     17.0      28.0
# fnlwgt          32561.0  189778.366512  105549.977697  12285.0  117827.0
# education.num   32561.0      10.080679       2.572720      1.0       9.0
# capital.gain    32561.0    1077.648844    7385.292085      0.0       0.0
# capital.loss    32561.0      87.303830     402.960219      0.0       0.0
# hours.per.week  32561.0      40.437456      12.347429      1.0      40.0
#
#                      50%       75%        max
# age                 37.0      48.0       90.0
# fnlwgt          178356.0  237051.0  1484705.0
# education.num       10.0      12.0       16.0
# capital.gain         0.0       0.0    99999.0
# capital.loss         0.0       0.0     4356.0
# hours.per.week      40.0      45.0       99.0

# %% [markdown]
# #  Exploratory Data Analysis-EDA

# %%
report=sv.analyze(data)
# Out:
#                                              |                                             | [  0%]   00:00 ->…

# %%
report.show_html() #check sweetviz html report
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
data.income.value_counts()
# Out:
# <=50K    24720
# >50K      7841
# Name: income, dtype: int64

# %%
income=data["income"].value_counts()
sns.barplot(x=income.index,y=income.values)
plt.xlabel("class")
plt.ylabel("no. of people")
# Out:
# Text(0, 0.5, 'no. of people')

# %%
sns.histplot(x=data['age'],kde=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
data.age.skew()
# Out:
# 0.5587433694130483

# %%
data.workclass.unique()
# Out:
# array(['?', 'Private', 'State-gov', 'Federal-gov', 'Self-emp-not-inc',
#        'Self-emp-inc', 'Local-gov', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
data.workclass.value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
data.fnlwgt.skew()
# Out:
# 1.4469800945789828

# %%
sns.boxplot(x=data["fnlwgt"])
# Out:
# <AxesSubplot:xlabel='fnlwgt'>

# %%
#removing outliers
q1=data['fnlwgt'].quantile(0.25)
q3=data['fnlwgt'].quantile(0.75)
iqr=q3-q1
lf=q1-1.5*iqr
uf=q3+1.5*iqr
ind1=data[data['fnlwgt']<lf].index
ind2=data[data['fnlwgt']>uf].index

# %%
data.drop(ind2,axis=0,inplace=True)

# %%
data.shape
# Out:
# (31569, 15)

# %%
data.fnlwgt.skew()
# Out:
# 0.4114384008149891

# %%
educn = data['education.num'].value_counts()

sns.barplot(x=educn.index,y=educn.values)
plt.xlabel("years")
plt.ylabel("no. of people")
# Out:
# Text(0, 0.5, 'no. of people')

# %%
data["education.num"].skew()
# Out:
# -0.3019495001919037

# %%
sns.boxplot(x=data["education.num"])
# Out:
# <AxesSubplot:xlabel='education.num'>

# %%
#removing outliers
q1=data['education.num'].quantile(0.25)
q3=data['education.num'].quantile(0.75)
iqr=q3-q1
lf=q1-1.5*iqr
uf=q3+1.5*iqr
ind1=data[data['education.num']<lf].index
ind2=data[data['education.num']>uf].index

# %%
data.drop(ind1,axis=0,inplace=True)

# %%
data['education.num'].skew()
# Out:
# 0.26948676703734126

# %%
data['marital.status'].value_counts()
# Out:
# Married-civ-spouse       13945
# Never-married            10064
# Divorced                  4223
# Separated                  938
# Widowed                    885
# Married-spouse-absent      357
# Married-AF-spouse           21
# Name: marital.status, dtype: int64

# %%
marital = data['marital.status'].value_counts()
plt.figure(figsize=(10, 7))
plt.pie(marital.values, labels=marital.index, startangle=10, shadow=True, autopct='%1.1f%%')
plt.legend()
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
data.corr()
# Out:
#                      age    fnlwgt  education.num  capital.gain  capital.loss  \
# age             1.000000 -0.062251       0.109530      0.082924      0.059513
# fnlwgt         -0.062251  1.000000      -0.019848      0.002733     -0.001448
# education.num   0.109530 -0.019848       1.000000      0.128486      0.088196
# capital.gain    0.082924  0.002733       0.128486      1.000000     -0.032402
# capital.loss    0.059513 -0.001448       0.088196     -0.032402      1.000000
# hours.per.week  0.085331 -0.017602       0.161760      0.077107      0.054914
#
#                 hours.per.week
# age                   0.085331
# fnlwgt               -0.017602
# education.num         0.161760
# capital.gain          0.077107
# capital.loss          0.054914
# hours.per.week        1.000000

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['income'] = le.fit_transform(data['income'])

# %%
data.income.value_counts()
# Out:
# 0    22861
# 1     7572
# Name: income, dtype: int64

# %%
sns.pairplot(data=data)

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #  Data Preprocessing

# %%
data = data.replace('?', np.nan)

# %%
data.isnull().sum()
# Out:
# age                  0
# workclass         1664
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1669
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     527
# income               0
# dtype: int64

# %%
round((data.isnull().sum() / data.isnull().count()) * 100, 2).astype(str) + ' %'
# Out:
# age                0.0 %
# workclass         5.47 %
# fnlwgt             0.0 %
# education          0.0 %
# education.num      0.0 %
# marital.status     0.0 %
# occupation        5.48 %
# relationship       0.0 %
# race               0.0 %
# sex                0.0 %
# capital.gain       0.0 %
# capital.loss       0.0 %
# hours.per.week     0.0 %
# native.country    1.73 %
# income             0.0 %
# dtype: object

# %%
null_columns = ['workclass', 'occupation', 'native.country']
for i in null_columns:
    data[i].fillna(data[i].mode()[0], inplace=True)

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
#all categorical column converted through label encoder
for columns in data.columns:
    if data[columns].dtypes == 'object':
        le = LabelEncoder()
        data[columns] = le.fit_transform(data[columns])

# %% [markdown]
# # Featuring Engineering

# %%
x = data.drop('income', axis=1)
y = data['income']

# %%
x = x.drop(['workclass', 'education', 'race', 'sex',
            'capital.loss', 'native.country'], axis=1)

# %%
from sklearn.preprocessing import StandardScaler
for col in x.columns:
    scaler = StandardScaler()
    x[col] = scaler.fit_transform(x[col].values.reshape(-1, 1))

# %%
x.head()
# Out:
#         age    fnlwgt  education.num  marital.status  occupation  \
# 0  3.831475 -1.170247      -0.600998        2.254961    0.718189
# 1  3.237615 -0.530092      -0.600998        2.254961   -0.782439
# 2  2.049894  0.079946      -0.154624        2.254961    0.718189
# 4  0.194081  0.981418      -0.154624        1.591017    0.718189
# 5 -0.325547  0.433220      -0.600998       -1.728701    0.217980
#
#    relationship  capital.gain  hours.per.week
# 0     -0.281728     -0.147824       -0.042127
# 1     -0.281728     -0.147824       -1.824770
# 2      1.582420     -0.147824       -0.042127
# 4      0.961037     -0.147824       -0.042127
# 5      1.582420     -0.147824        0.363019

# %%
#this data set is imbalanced

# %%
from sklearn.utils import resample

# %%
data.income.value_counts()
# Out:
# 0    22861
# 1     7572
# Name: income, dtype: int64

# %%
data_majority=data[data['income']==0]
data_minority=data[data['income']==1]

# %%
numofmajority=data[data['income']==0]['income'].count()

# %%
numofmajority
# Out:
# 22861

# %%
data_resampling=resample(data_minority,replace=True,n_samples=numofmajority)

# %%
data_combine=pd.concat([data_resampling,data_majority])

# %%
data_combine.head()
# Out:
#        age  workclass  fnlwgt  education  education.num  marital.status  \
# 17864   45          3   26502          6             13               2
# 3059    46          3  173243         11             10               2
# 969     63          3  383058          6             13               2
# 20986   50          3  237868          9             14               2
# 20135   31          3  159123          6             13               2
#
#        occupation  relationship  race  sex  capital.gain  capital.loss  \
# 17864           2             0     4    1             0             0
# 3059           12             0     4    1          5178             0
# 969            11             0     4    1             0          1848
# 20986           3             0     4    1             0             0
# 20135           9             0     4    1             0             0
#
#        hours.per.week  native.country  income
# 17864              72              38       1
# 3059               40              38       1
# 969                40              38       1
# 20986              50              38       1
# 20135              60              38       1

# %%
data_combine.income.value_counts()
# Out:
# 1    22861
# 0    22861
# Name: income, dtype: int64

# %%
x1 = data_combine.drop('income', axis=1)
y1 = data_combine['income']

# %%
x1 = x1.drop(['workclass', 'education', 'race', 'sex',
            'capital.loss', 'native.country'], axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x1,y1, test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (36577, 8)

# %%
x_test.shape
# Out:
# (9145, 8)

# %% [markdown]
# # Data Modeling

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()

# %%
log.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_log = log.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score(y_test,y_pred_log)
# Out:
# 0.6033898305084746

# %%
confusion_matrix(y_test,y_pred_log)
# Out:
# array([[2743, 1829],
#        [1798, 2775]], dtype=int64)

# %%
#knn classification
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
y_pred_knn=knn.predict(x_test)

# %%
confusion_matrix(y_test,y_pred_knn)
# Out:
# array([[2927, 1645],
#        [ 866, 3707]], dtype=int64)

# %%
accuracy_score(y_test,y_pred_knn)
# Out:
# 0.7254237288135593

# %%
#decision tree
from sklearn.tree import DecisionTreeClassifier
dec = DecisionTreeClassifier()

# %%
dec.fit(x_train, y_train)
y_pred_dec = dec.predict(x_test)

# %%
confusion_matrix(y_test,y_pred_dec)
# Out:
# array([[3901,  671],
#        [ 161, 4412]], dtype=int64)

# %%
accuracy_score(y_test,y_pred_knn)
# Out:
# 0.7254237288135593

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier
ran = RandomForestClassifier()
ran.fit(x_train, y_train)
y_pred_ran=ran.predict(x_test)

# %%
confusion_matrix(y_test,y_pred_ran)
# Out:
# array([[3990,  582],
#        [ 127, 4446]], dtype=int64)

# %%
accuracy_score(y_test,y_pred_ran)
# Out:
# 0.9224712957900492

# %%
#support vector machine
from sklearn.svm import SVC
svc = SVC()
svc.fit(x_train, y_train)
y_pred_svc=svc.predict(x_test)

# %%
confusion_matrix(y_test,y_pred_svc)
# Out:
# array([[4508,   64],
#        [3681,  892]], dtype=int64)

# %%
accuracy_score(y_test,y_pred_svc)
# Out:
# 0.590486604702023

# %% [markdown]
# # conclusion

# %% [markdown]
# hence best model for above data set is Random Forest Classifier with best accuracy score and best confusion matrix

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_ran))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.87      0.92      4572
#            1       0.88      0.97      0.93      4573
#
#     accuracy                           0.92      9145
#    macro avg       0.93      0.92      0.92      9145
# weighted avg       0.93      0.92      0.92      9145
